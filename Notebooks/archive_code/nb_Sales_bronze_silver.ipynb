# %%
# %sql
--Reading data from this bronze layer to silver layer
--SELECT * FROM intellibi_catalog.intellibi_bronze.dfMonthlySales;

# %%
# %sql
--SELECT * FROM intellibi_catalog.intellibi_silver.dfMonthlySales;

# %%
# %sql
--Inserting data into silver layer from bronze
INSERT INTO intellibi_catalog.intellibi_silver.dfMonthlySales
SELECT * FROM intellibi_catalog.intellibi_bronze.dfMonthlySales;
--WHERE CURRENT_TIMESTAMP() > ingest_ts;

# %%
# %sql
SELECT * FROM intellibi_catalog.intellibi_silver.dfmonthlysales;
