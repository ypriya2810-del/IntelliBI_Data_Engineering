-- %%
CREATE OR REPLACE TABLE intellibi_catalog.intellibi_gold.refinedMonthlySales
(
   sale_id INTEGER, product string, category string, quantity INTEGER, price DOUBLE,
   sale_date DATE, region string, 
   initial_load_ts timestamp,
   last_updt_ts timestamp

 );

--describe intellibi_catalog.intellibi_silver.cleansedMonthlySales;
--It describe the history of table
--describe history intellibi_catalog.intellibi_bronze.rawMonthlySales;
--SELECT * FROM intellibi_catalog.intellibi_gold.refinedMonthlySales;
--DROP TABLE intellibi_catalog.intellibi_bronze.dfMonthlySales;
--SELECT * FROM intellibi_catalog.intellibi_gold.refinedMonthlySales;
--DROP TABLE intellibi_catalog.intellibi_silver.dfMonthlySales;
--SELECT * FROM intellibi_catalog.intellibi_silver.cleansedMonthlySales;
