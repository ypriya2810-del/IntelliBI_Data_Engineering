-- %%
--TRUNCATE TABLE intellibi_catalog.intellibi_bronze.rawMonthlySales;
--TRUNCATE TABLE intellibi_catalog.intellibi_silver.cleansedMonthlySales;
--TRUNCATE TABLE intellibi_catalog.intellibi_gold.refinedMonthlySales;





--SELECT * FROM intellibi_catalog.intellibi_bronze.rawMonthlySales;
--SELECT * FROM intellibi_catalog.intellibi_silver.cleansedMonthlySales;
--SELECT * FROM intellibi_catalog.intellibi_gold.refinedMonthlySales;
