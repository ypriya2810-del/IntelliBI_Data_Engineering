-- %%
CREATE OR REPLACE TABLE intellibi_catalog.intellibi_silver.cleansedCustomer
(
   customer_id integer, customer_name string, email string,
   phone string, address string,
   city string, state string, 
   country string, zip_code string, 
   segment string, ingest_ts timestamp
 );

--describe intellibi_catalog.intellibi_silver.cleansedCustomer;
--It describe the history of table
--describe history intellibi_catalog.intellibi_silver.cleansedCustomer;
SELECT * FROM intellibi_catalog.intellibi_silver.cleansedCustomer;

--DROP TABLE intellibi_catalog.intellibi_silver.cleansedCustomer;
