# %%
# %sql
truncate table intellibi_catalog.intellibi_bronze.dfMonthlySales;
truncate table intellibi_catalog.intellibi_silver.dfMonthlySales;
truncate table intellibi_catalog.intellibi_gold.dfMonthlySales;

# %%
# %sql
SELECT count(*) FROM intellibi_catalog.intellibi_bronze.dfMonthlySales;
--SELECT * FROM intellibi_catalog.intellibi_gold.dfMonthlySales;

# %%
# %sql
SELECT count(*) FROM intellibi_catalog.intellibi_silver.dfMonthlySales;

# %%
# %sql
SELECT count(*) FROM intellibi_catalog.intellibi_gold.dfMonthlySales;
