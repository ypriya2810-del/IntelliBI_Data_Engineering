-- %%
CREATE OR REPLACE TABLE intellibi_catalog.intellibi_bronze.rawCustomer
(
   customer_id string, customer_name string, email string,
   phone string, address string,
   city string, state string, 
   country string, zip_code string, 
   segment string, ingest_ts timestamp
);

--describe intellibi_catalog.intellibi_bronze.rawCustomer;
--It describe the history of table
--describe history intellibi_catalog.intellibi_bronze.rawCustomer;
--SELECT * FROM intellibi_catalog.intellibi_bronze.rawCustomer;
--DROP TABLE intellibi_catalog.intellibi_bronze.rawCustomer;
