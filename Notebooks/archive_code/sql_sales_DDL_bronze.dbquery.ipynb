-- %%
CREATE OR REPLACE TABLE intellibi_catalog.intellibi_bronze.rawMonthlySales
(
   sale_id string, product string, category string, quantity string, price string,
   sale_date string, region string, 
   ingest_ts timestamp

 );

describe intellibi_catalog.intellibi_bronze.rawMonthlySales;
--It describe the history of table
--describe history intellibi_catalog.intellibi_bronze.rawMonthlySales;
SELECT * FROM intellibi_catalog.intellibi_bronze.rawMonthlySales;
--DROP TABLE intellibi_catalog.intellibi_bronze.dfMonthlySales;
